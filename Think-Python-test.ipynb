# %% [markdown]
# # Think Python: Week 0
#
# ## About These Slides
# These slides are expressed in Markdown inside an iPython (Jupyter) notebook. Don't worry if you don't know what that means, we'll get to it later on. The key points are:
#
# * It's easy to write and read the text, as well as present it as slides.
# * The slides include the ability to interactively evaluate Python expressions, which we'll use a *lot *in class.
# * The slides will be available in Github so you can go back to them later, get your own copies, etc.
# * I'll add links for further reading, with challenge levels:
#     -   ![black diamond][diamond] = a little more challenging
#     -   ![black diamond][diamond]![black diamond][diamond] = pretty
#         tough
#     -   ![black diamond][diamond]![black diamond][diamond]![black diamond][diamond] = for more experienced programmers
#
# ## More About These Slides
#
# -   Python names and values will look like this: `print`
# -   Python code for typing at the interpreter will look like this:
#
#         >>> print $a
#           File "<stdin>", line 1
#             print $a
#                   ^
#         SyntaxError: invalid syntax
#
# or like this:
#
#     >>> print 'a'
#      a
#
# ## Goals for today
#
# [comment]: <> (My goal is to always provide these: ask if i don't)
#
# * Orientation, expectations, preliminaries
# * Be able to run Python on your own
#
# ## Goals for the class
#
# * Introduce basic concepts in Computer Science
# * Provide basic Python proficiency
#
# [comment]: <> (If you're smart enough to work at Logos, you're smart enough to
#     learn some Python)
#
# * Help you get started as an independent learner with Python and
#     programming
#
#     <div class="comment">
#
#     So you can carry on yourself. Gal 6:7 the law of the harvest: "You
#     will always harvest what you plant."
#
#     </div>
#
# -   Have fun, learn to enjoy programming, open some new opportunities
# -   Focus on practical tasks and *getting things done*
#
#
# ## My Role
#
# -   Enlarge the picture and focus attention
# -   Connect to the Logos context and make things practical
# -   Get you unstuck
# -   Streamline learning with experience where possible
# -   Help you find appropriate challenges and solutions
#
# ## My Qualifications
#
# -   No degree in computer science (gasp!)
# -   BA in anthopology and linguistics (Occidental College)
# -   MA in computational linguistics (UCLA)
# -   Coursework in distance education (UMUC)
# -   Visiting professor at Claremont McKenna College (CA), Nyack College
#     (DC)
#
# ## My Qualifications (con't)
#
# ![my language experience](languages.jpg)
#
# [comment]: <> "This should encourage you: many programmers are mostly self-taught."
#
# ## How to Ask Me Questions
#
# [comment]: <> "There are 15 of you, and only 1 of me: this is a side-task for me too.; It's a very valuable skill to learn to ask for help, and break the 'lone wolf' mentality.; Both you and your friend may learn from this experience"
#
# * First: ask on [the Faithlife group for Think Python](https://faithlife.com/think-python/activity)
# * Okay: send me an email
# * Better: send me an email like this:
#
#     > When I type
#     >
#     >      >>> import swampy
#     >
#     >  what I see is
#     >
#     >      Traceback (most recent call last):
#     >      File "\<stdin\>", line 1, in \<module\>
#     >      ImportError: No module named swampy
#     >
#     >  What's wrong here?
#
# [comment]: <> "This tells me *exactly* what you're doing, and *exactly* what results you're getting. Critically important: i can try to reproduce your problem"
#
# * ![no instant messenger](no-im.png)
#
# [comment]: <> "Unless you're my boss, there's no good scenario for communicating with me via IM. Instead, i'll probably ignore you."
#
# ## Classes and Schedule
#
# * Class attendance is your option, and only if it helps *you*
# * No need to turn in assignments unless you want feedback
# * We'll use Faithlife to record Frequently Asked Questions and other useful information
#
# ## Getting Set Up
#
# * [ActivePython](http://www.activestate.com/activepython/downloads) 2.7 for Windows (not version 3)
# * Decide on an editing environment
#
# [comment]: <> "Editor: plain text, tabs vs. spaces, line numbers, preferably Unicode; If no other basis, use IDLE as default"
# * Bring a laptop to class if at all possible
# * Demonstration: show the interpreter and run a script.
#
# ## Why Python?
#
# * Good language for learning: readable, coherent, high-quality, [well-documented](http://docs.python.org/index.html)
# * Highly productive: compact, interactive evaluation
#
# [comment]: <> "Interactive evaluation is the greatest thing since sliced bread"
#
# -   Well-suited to utility programming
#
# [comment]: <> "How this differs from app development"
# * Portable, open-source
# * Lots of standard libraries ("batteries included") as well as third-party modules
#
# ## Learning by Doing
#
# > "Computer science education cannot make anybody an expert programmer any more than studying brushes and pigment can make somebody an expert painter"
# > -- Eric Raymond, author of The New Hacker's Dictionary.
#
# [comment]: <> "Me talking is 'education'. You programming is painting.  "
#
# ## 1.3 Errors
#
# * Syntax errors are typically obvious (though not necessarily the solution). Some common ones when starting out:
#     -   Missing or mismatched quotes
#     -   Undefined variables
#     -   Incompatible types for some operation
#     -   An editor with line numbers will help
# -   Semantic errors are much trickier. Some common ones when starting
#     out:
#     -   You "know" what a value is (but you're wrong)
#
# [comment]: <> "Particular problem when processing lots of data and you've only looked at a little of it"
# [comment]: <> "You misunderstand how a function works; there are side-effects"
#
# -   **Programming is about narrowing the gap between your intentions,
#     your program, and reality**
#
# ## 1.6 Debugging
#
# * Essential to work with a computer, typically via the interpreter, until you really know what's happening
# * *Type it in*: it's more work, but gives you a better feel for what works, and *more immediate feedback on your mistakes* (critical to incremental improvement!)
#
# ## Additional Resources
#
# * [Official Python 2.7
#     Documentation](http://docs.python.org/index.html)
# * ![black diamond][diamond]Why you can't learn programming quickly:
#     [Teach Yourself Programming in Ten
#     Years](http://norvig.com/21-days.html) by Peter Norvig, head of
#     research at Google
# -   ![black diamond][diamond]![black diamond][diamond]![black diamond][diamond][What IDE to use for
#     Python](http://stackoverflow.com/questions/81584/what-ide-to-use-for-python)
#
#
# [diamond]: bd.png "Black diamond means challenge"

# %%
print 2 + 3
# Out:
# 5
